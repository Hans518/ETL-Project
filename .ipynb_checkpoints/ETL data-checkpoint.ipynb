# %%
import pandas as pd
import json
import pprint
from sqlalchemy import create_engine
import os
import csv

# %%
us_videos_csv = "youtube-new/USvideos.csv"
us_videos_df = pd.read_csv(us_videos_csv)
us_videos_df['country_id'] = "us"
us_videos_df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
ca_videos_csv = "youtube-new/CAvideos.csv"
ca_videos_df = pd.read_csv(ca_videos_csv)
ca_videos_df['country_id'] = "ca"
ca_videos_df.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
de_videos_csv = "youtube-new/DEvideos.csv"
de_videos_df = pd.read_csv(de_videos_csv)
de_videos_df['country_id'] = "de"
de_videos_df.head()
# Out:
#       video_id trending_date  \
# 0  LgVi6y5QIjM      17.14.11
# 1  Bayt7uQith4      17.14.11
# 2  1ZAPwfrtAFY      17.14.11
# 3  AHtypnRk7JE      17.14.11
# 4  ZJ9We4bjcg0      17.14.11
#
#                                                title            channel_title  \
# 0  Sing zu Ende! | Gesangseinlagen vom Feinsten |...                inscope21
# 1  Kinder ferngesteuert im Kiosk! Erwachsene abzo...  LUKE! Die Woche und ich
# 2  The Trump Presidency: Last Week Tonight with J...          LastWeekTonight
# 3                                Das Fermi-Paradoxon        100SekundenPhysik
# 4           18 SONGS mit Kelly MissesVlog (Sing-off)                     rezo
#
#    category_id              publish_time  \
# 0           24  2017-11-13T17:08:49.000Z
# 1           23  2017-11-12T22:30:01.000Z
# 2           24  2017-11-13T07:30:00.000Z
# 3           27  2017-11-12T15:00:01.000Z
# 4           24  2017-11-12T13:10:36.000Z
#
# ...

# %%
fr_videos_csv = "youtube-new/FRvideos.csv"
fr_videos_df = pd.read_csv(fr_videos_csv)
fr_videos_df['country_id'] = "fr"
fr_videos_df.head()
# Out:
#       video_id trending_date  \
# 0  Ro6eob0LrCY      17.14.11
# 1  Yo84eqYwP98      17.14.11
# 2  ceqntSXE-10      17.14.11
# 3  WuTFI5qftCE      17.14.11
# 4  ee6OFs8TdEg      17.14.11
#
#                                                title        channel_title  \
# 0           Malika LePen : Femme de Gauche - Trailer  Le Raptor Dissident
# 1  LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce,...              Le Labo
# 2  DESSINS ANIMÉS FRANÇAIS VS RUSSES 2 - Daniil...      Daniil le Russe
# 3                    PAPY GRENIER - METAL GEAR SOLID    Joueur Du Grenier
# 4  QUI SAUTERA LE PLUS HAUT ? (VÉLO SKATE ROLLER ...    Aurelien Fontenoy
#
#    category_id              publish_time  \
# 0           24  2017-11-13T17:32:55.000Z
# 1           24  2017-11-12T15:00:02.000Z
# 2           23  2017-11-13T17:00:38.000Z
# 3           20  2017-11-12T17:00:02.000Z
# 4           17  2017-11-13T16:30:03.000Z
#
#                                                 tags   views  likes  dislikes  \
# ...

# %%
gb_videos_csv = "youtube-new/GBvideos.csv"
gb_videos_df = pd.read_csv(gb_videos_csv)
gb_videos_df['country_id'] = "gb"
gb_videos_df.head()
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU      17.14.11
# 1  3s1rvMFUweQ      17.14.11
# 2  n1WpP7iowLc      17.14.11
# 3  PUTEiSjKwJU      17.14.11
# 4  rHwDegptbI4      17.14.11
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
#
#                 channel_title  category_id              publish_time  \
# 0                  John Lewis           26  2017-11-10T07:38:29.000Z
# 1         Saturday Night Live           24  2017-11-12T06:24:44.000Z
# 2                  EminemVEVO           10  2017-11-10T17:00:03.000Z
# 3  Salford City Football Club           17  2017-11-13T02:30:38.000Z
# 4            Cute Girl Videos           25  2017-11-13T01:45:13.000Z
#
# ...

# %%
in_videos_csv = "youtube-new/INvideos.csv"
in_videos_df = pd.read_csv(in_videos_csv)
in_videos_df['country_id'] = "in"
in_videos_df.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc      17.14.11
# 1  zUZ1z7FwLc8      17.14.11
# 2  10L1hZ9qa58      17.14.11
# 3  N1vE8iiEg64      17.14.11
# 4  kJzGH0PVQHQ      17.14.11
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...          HJ NEWS
# 2  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 3                     Eruma Saani | Tamil vs English      Eruma Saani
# 4  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
#
#    category_id              publish_time  \
# 0            1  2017-11-12T12:20:39.000Z
# 1           25  2017-11-13T05:43:56.000Z
# 2           24  2017-11-12T15:48:08.000Z
# 3           23  2017-11-12T07:08:48.000Z
# 4           24  2017-11-13T01:14:16.000Z
#
#                                                 tags    views  likes  \
# ...

# %%
jp_videos_csv = "youtube-new/JPvideos.csv"
jp_videos_df = pd.read_csv(jp_videos_csv, encoding='cp850')
jp_videos_df.head(50)

# jp_videos_csv = os.path.join('youtube-new/JPvideos.csv')

# video_id = []
# trending_date = []
# title = []
# channel_title = []
# category_id = []
# publish_time = []
# tags = []
# views = []
# like = []
# dislikes = []
# comment_count = []
# thumbnail_link = []
# comments_disabled = []
# ratings_disabled = []
# video_error_or_removed = []
# description = []


# with open(jp_videos_csv, 'r', encoding='utf_32') as csvfile:
#     csvreader = csv.reader(csvfile, delimiter=",")
#     header = next(csvreader)
    
#     for row in csvreader:
#         try:
#             video_id.append(row[0])
#             trending_date.append(row[1])
#             title.append(row[2])
#             channel_title.append(row[3])
#             publish_time.append(row[4])
#             tags.append(row[5])
#             views.append(row[6])
#             like.append(row[7])
#             dislikes.append(row[8])
#             comment_count.append(row[9])
#             thumbnail_link.append(row[10])
#             comments_disabled.append(row[11])
#             ratings_disabled.append(row[12])
#             video_error_or_removed.append(row[13])
#             description.append(row[14])
            
#         except UnicodeDecodeError:
#             print("'utf-8' codec can't decode bytes in position 7838-7839: invalid continuation byte")
        
        
        
        
          
# date_data = []
# for d in term_date:
#     try:
#         date_conv = datetime.datetime.strptime(d, '%m/%d/%Y').date()
#         date_data.append(date_conv)
#     except ValueError:
#         date_data.append("Backup end not found")

# term_date = date_data

# termed_workers_df = pd.DataFrame({"First Name" : first,
#                                  "Last Name" : last,
#                                  "Email": email,
#                                  "term_date" : term_date})
# Out:
#        video_id trending_date  \
# 0   5ugKfHgsmYw      18.07.02
# 1   ohObafdd34Y      18.07.02
# 2   aBr2kKAHN6M      18.07.02
# 3   5wNnwChvmsQ      18.07.02
# 4   B7J47qFvdsk      18.07.02
# 5   OIDfjdGERr8      18.07.02
# 6   KqtWo-4A0LU      18.07.02
# 7   MPQaySneSUc      18.07.02
# 8   zIhc0rXajCk      18.07.02
# 9   FVPmVIfl3-o      18.07.02
# 10  CcWHJuzPUKY      18.07.02
# 11  nvSvrGUaRL0      18.07.02
# 12  GbHQfKUVEqk      18.07.02
# 13  TC-ipmLi9PA      18.07.02
# 14  UQVs2qDBe10      18.07.02
# 15  cXopRwPxg2M      18.07.02
# 16  bFrhcY9exgo      18.07.02
# 17  bvgF6esNfeQ      18.07.02
# 18  ylojY8-BfWU      18.07.02
# 19  zr99xwEg6Pg      18.07.02
# 20  u1LbK98Yphs      18.07.02
# 21  29Gd024WhDA      18.07.02
# 22  iP3symHIsUs      18.07.02
# 23  0aH2JyPKkcQ      18.07.02
# 24  B_v4nRnOs4A      18.07.02
# 25  pVxOVlm_lE8      18.07.02
# 26  _C1pZ0KL0MM      18.07.02
# 27  6sexVZpv5RI      18.07.02
# 28  vmd4px8348Y      18.07.02
# 29  kKt7R582Umk      18.07.02
# ...

# %%
# kr_videos_csv = "youtube-new/KRvideos.csv"
# kr_videos_df = pd.read_csv(kr_videos_csv)
# kr_videos_df.head(50)

kr_videos_csv = os.path.join('youtube-new/KRvideos.csv')

video_id = []
trending_date = []
title = []
channel_title = []
category_id = []
publish_time = []
tags = []
views = []
like = []
dislikes = []
comment_count = []
thumbnail_link = []
comments_disabled = []
ratings_disabled = []
video_error_or_removed = []
description = []


with open(kr_videos_csv, 'r', encoding='iso2022_kr') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=",")
    header = next(csvreader)
    
    for row in csvreader:
        try:
            video_id.append(row[0])
            trending_date.append(row[1])
            title.append(row[2])
            channel_title.append(row[3])
            publish_time.append(row[4])
            tags.append(row[5])
            views.append(row[6])
            like.append(row[7])
            dislikes.append(row[8])
            comment_count.append(row[9])
            thumbnail_link.append(row[10])
            comments_disabled.append(row[11])
            ratings_disabled.append(row[12])
            video_error_or_removed.append(row[13])
            description.append(row[14])
            
        except UnicodeDecodeError:
            print("'utf-8' codec can't decode bytes in position 7838-7839: invalid continuation byte")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-49-12539cc94504> in <module>
#      25 with open(kr_videos_csv, 'r', encoding='iso2022_kr') as csvfile:
#      26     csvreader = csv.reader(csvfile, delimiter=",")
# ---> 27     header = next(csvreader)
#      28
#      29     for row in csvreader:
#
# UnicodeDecodeError: 'iso2022_kr' codec can't decode byte 0xec in position 215: illegal multibyte sequence

# %%
mx_videos_csv = "youtube-new/MXvideos.csv"
mx_videos_df = pd.read_csv(mx_videos_csv,  encoding='ANSI')
mx_videos_df['country_id'] = "mx"
mx_videos_df.head()

# mx_videos_csv = os.path.join('youtube-new/MXvideos.csv')

# video_id = []
# trending_date = []
# title = []
# channel_title = []
# category_id = []
# publish_time = []
# tags = []
# views = []
# like = []
# dislikes = []
# comment_count = []
# thumbnail_link = []
# comments_disabled = []
# ratings_disabled = []
# video_error_or_removed = []
# description = []


# with open(mx_videos_csv, 'r', encoding='utf-8') as csvfile:
#     csvreader = csv.reader(csvfile, delimiter=",")
#     header = next(csvreader)
    
#     for row in csvreader:
#         print(row)
#         try:
#             video_id.append(row[0])
#             trending_date.append(row[1])
#             title.append(row[2])
#             channel_title.append(row[3])
#             publish_time.append(row[4])
#             tags.append(row[5])
#             views.append(row[6])
#             like.append(row[7])
#             dislikes.append(row[8])
#             comment_count.append(row[9])
#             thumbnail_link.append(row[10])
#             comments_disabled.append(row[11])
#             ratings_disabled.append(row[12])
#             video_error_or_removed.append(row[13])
#             description.append(row[14])
            
#         except UnicodeDecodeError:
#             print("'utf-8' codec can't decode bytes in position 7838-7839: invalid continuation byte")
# Out:
#       video_id trending_date  \
# 0  SbOwzAl9ZfQ      17.14.11
# 1  klOV6Xh-DnI      17.14.11
# 2  6L2ZF7Qzsbk      17.14.11
# 3  hcY52MFWMDM      17.14.11
# 4  _OXDcGPVAa4      17.14.11
#
#                                                title  \
# 0                     CapÃ­tulo 12 | MasterChef 2017
# 1  ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
# 2           LOUIS CKAGÃ“ - EL PULSO DE LA REPÃšBLICA
# 3   Sismo de 6.7 sacude Costa Rica 12 Noviembre 2017
# 4           DOG HACKS | MUSAS LESSLIE LOS POLINESIOS
#
#                channel_title  category_id              publish_time  \
# 0            MasterChef 2017           24  2017-11-13T06:06:22.000Z
# 1   Micky Contreras Martinez           22  2017-11-13T05:11:58.000Z
# 2  El Pulso De La RepÃºblica           25  2017-11-13T17:00:02.000Z
# 3                   Casanare           25  2017-11-13T03:47:10.000Z
# 4                      Musas           26  2017-11-13T19:17:48.000Z
#
# ...

# %%
ru_videos_csv = "youtube-new/RUvideos.csv"
ru_videos_df = pd.read_csv(ru_videos_csv, encoding='cp866')
ru_videos_df.head(50)
# ru_videos_csv = os.path.join('youtube-new/RUvideos.csv')

# video_id = []
# trending_date = []
# title = []
# channel_title = []
# category_id = []
# publish_time = []
# tags = []
# views = []
# like = []
# dislikes = []
# comment_count = []
# thumbnail_link = []
# comments_disabled = []
# ratings_disabled = []
# video_error_or_removed = []
# description = []


# with open(ru_videos_csv, 'r', encoding='utf-8') as csvfile:
#     csvreader = csv.reader(csvfile, delimiter=",")
#     header = next(csvreader)
    
#     for row in csvreader:
#         print(row[0])
# Out:
#        video_id trending_date  \
# 0   gDuslQ9avLc      17.14.11
# 1   AOCJIFEA_jE      17.14.11
# 2   VAWNQDgwwOM      17.14.11
# 3   gknkFwKQfHg      17.14.11
# 4   3sYvZcwzZr8      17.14.11
# 5   SLF34Gt_UxQ      17.14.11
# 6   YVcroDDi24s      17.14.11
# 7   TZdNwUSgRHc      17.14.11
# 8   YxEJVGfP74Y      17.14.11
# 9   oZYT_vC4-pc      17.14.11
# 10  3KdggIRWiR0      17.14.11
# 11  6X4YapxVq0A      17.14.11
# 12  Omdo0bhd4Q8      17.14.11
# 13  CMRuwAxwFzk      17.14.11
# 14  t9NxCOsmzcY      17.14.11
# 15  sI2Mpp9AWRg      17.14.11
# 16  ZYNJKWCFrH8      17.14.11
# 17  ss0q7YJ8weU      17.14.11
# 18  6846jSXLg9o      17.14.11
# 19  3U3FcX9NYXg      17.14.11
# 20  Va4KRV9c95o      17.14.11
# 21  bpYfzrFJMNU      17.14.11
# 22  DS7OiDdSkR0      17.14.11
# 23  Gmq88u0W81Y      17.14.11
# 24  jqFN6Wc877I      17.14.11
# 25  kK-9T4kcZOY      17.14.11
# 26  JCBl3_780Cc      17.14.11
# 27  d9ndEyk2lBw      17.14.11
# 28  L_OP79MnELA      17.14.11
# 29  qHL7mEzDxhI      17.14.11
# ...

# %%
us_videos_json = open('youtube-new/US_category_id.json')
data = json.load(us_videos_json)
video_categories = data['items']

#pprint.pprint(video_categories)

etag = []
id = []
kind = []
assignable = []
channelId = []
title = []
snippet = []

for x in video_categories: 
    etag.append(x['etag'])
    id.append(x['id'])
    snippet.append(x['snippet'])
    
for s in snippet:
    title.append(s['title'])
    

categories = pd.DataFrame({"category_id" : id,
                          "category_name" : title})

#categories

# %%
ca_videos_json = open('youtube-new/CA_category_id.json')
data = json.load(ca_videos_json)
video_categories = data['items']

#pprint.pprint(video_categories)

etag = []
id = []
kind = []
assignable = []
channelId = []
title = []
snippet = []

for x in video_categories: 
    etag.append(x['etag'])
    id.append(x['id'])
    snippet.append(x['snippet'])
    
for s in snippet:
    title.append(s['title'])
    

categories = pd.DataFrame({"category_id" : id,
                          "category_name" : title})

#categories

# %%
print(title)
# Out:
# ['Film & Animation', 'Autos & Vehicles', 'Music', 'Pets & Animals', 'Sports', 'Short Movies', 'Travel & Events', 'Gaming', 'Videoblogging', 'People & Blogs', 'Comedy', 'Entertainment', 'News & Politics', 'Howto & Style', 'Education', 'Science & Technology', 'Nonprofits & Activism', 'Movies', 'Anime/Animation', 'Action/Adventure', 'Classics', 'Comedy', 'Documentary', 'Drama', 'Family', 'Foreign', 'Horror', 'Sci-Fi/Fantasy', 'Thriller', 'Shorts', 'Shows', 'Trailers']

# %%
de_videos_json = open('youtube-new/DE_category_id.json')
data = json.load(de_videos_json)
video_categories = data['items']

#pprint.pprint(video_categories)

etag = []
id = []
kind = []
assignable = []
channelId = []
title = []
snippet = []

for x in video_categories: 
    etag.append(x['etag'])
    id.append(x['id'])
    snippet.append(x['snippet'])
    
for s in snippet:
    title.append(s['title'])
    

categories = pd.DataFrame({"category_id" : id,
                          "category_name" : title})

categories
# Out:
#    category_id         category_name
# 0            1      Film & Animation
# 1            2      Autos & Vehicles
# 2           10                 Music
# 3           15        Pets & Animals
# 4           17                Sports
# 5           18          Short Movies
# 6           19       Travel & Events
# 7           20                Gaming
# 8           21         Videoblogging
# 9           22        People & Blogs
# 10          23                Comedy
# 11          24         Entertainment
# 12          25       News & Politics
# 13          26         Howto & Style
# 14          27             Education
# 15          28  Science & Technology
# 16          30                Movies
# 17          31       Anime/Animation
# 18          32      Action/Adventure
# 19          33              Classics
# 20          34                Comedy
# 21          35           Documentary
# 22          36                 Drama
# 23          37                Family
# ...

# %%
fr_videos_json = open('youtube-new/FR_category_id.json')
data = json.load(fr_videos_json)
video_categories = data['items']

#pprint.pprint(video_categories)

etag = []
id = []
kind = []
assignable = []
channelId = []
title = []
snippet = []

for x in video_categories: 
    etag.append(x['etag'])
    id.append(x['id'])
    snippet.append(x['snippet'])
    
for s in snippet:
    title.append(s['title'])
    

categories = pd.DataFrame({"category_id" : id,
                          "category_name" : title})

categories
# Out:
#    category_id         category_name
# 0            1      Film & Animation
# 1            2      Autos & Vehicles
# 2           10                 Music
# 3           15        Pets & Animals
# 4           17                Sports
# 5           18          Short Movies
# 6           19       Travel & Events
# 7           20                Gaming
# 8           21         Videoblogging
# 9           22        People & Blogs
# 10          23                Comedy
# 11          24         Entertainment
# 12          25       News & Politics
# 13          26         Howto & Style
# 14          27             Education
# 15          28  Science & Technology
# 16          30                Movies
# 17          31       Anime/Animation
# 18          32      Action/Adventure
# 19          33              Classics
# 20          34                Comedy
# 21          35           Documentary
# 22          36                 Drama
# 23          37                Family
# ...

# %%
jp_videos_json = open('youtube-new/JP_category_id.json')
data = json.load(jp_videos_json)
video_categories = data['items']

#pprint.pprint(video_categories)

etag = []
id = []
kind = []
assignable = []
channelId = []
title = []
snippet = []

for x in video_categories: 
    etag.append(x['etag'])
    id.append(x['id'])
    snippet.append(x['snippet'])
    
for s in snippet:
    title.append(s['title'])
    

categories = pd.DataFrame({"category_id" : id,
                          "category_name" : title})

categories
# Out:
#    category_id         category_name
# 0            1      Film & Animation
# 1            2      Autos & Vehicles
# 2           10                 Music
# 3           15        Pets & Animals
# 4           17                Sports
# 5           18          Short Movies
# 6           19       Travel & Events
# 7           20                Gaming
# 8           21         Videoblogging
# 9           22        People & Blogs
# 10          23                Comedy
# 11          24         Entertainment
# 12          25       News & Politics
# 13          26         Howto & Style
# 14          27             Education
# 15          28  Science & Technology
# 16          30                Movies
# 17          31       Anime/Animation
# 18          32      Action/Adventure
# 19          33              Classics
# 20          34                Comedy
# 21          35           Documentary
# 22          36                 Drama
# 23          37                Family
# ...

# %%
kr_videos_json = open('youtube-new/KR_category_id.json')
data = json.load(kr_videos_json)
video_categories = data['items']

#pprint.pprint(video_categories)

etag = []
id = []
kind = []
assignable = []
channelId = []
title = []
snippet = []

for x in video_categories: 
    etag.append(x['etag'])
    id.append(x['id'])
    snippet.append(x['snippet'])
    
for s in snippet:
    title.append(s['title'])
    

categories = pd.DataFrame({"category_id" : id,
                          "category_name" : title})

categories
# Out:
#    category_id         category_name
# 0            1      Film & Animation
# 1            2      Autos & Vehicles
# 2           10                 Music
# 3           15        Pets & Animals
# 4           17                Sports
# 5           18          Short Movies
# 6           19       Travel & Events
# 7           20                Gaming
# 8           21         Videoblogging
# 9           22        People & Blogs
# 10          23                Comedy
# 11          24         Entertainment
# 12          25       News & Politics
# 13          26         Howto & Style
# 14          27             Education
# 15          28  Science & Technology
# 16          30                Movies
# 17          31       Anime/Animation
# 18          32      Action/Adventure
# 19          33              Classics
# 20          34                Comedy
# 21          35           Documentary
# 22          36                 Drama
# 23          37                Family
# ...
